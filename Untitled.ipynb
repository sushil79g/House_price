# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('train.csv')

# %%
data.head(5)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
data.columns.tolist()
# Out:
# ['Id',
#  'MSSubClass',
#  'MSZoning',
#  'LotFrontage',
#  'LotArea',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'MasVnrArea',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinSF1',
#  'BsmtFinType2',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'KitchenQual',
#  'TotRmsAbvGrd',
#  'Functional',
#  'Fireplaces',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# ...

# %%
data.shape
# Out:
# (1460, 81)

# %%
data['PoolQC'].unique()
# Out:
# array([nan, 'Ex', 'Fa', 'Gd'], dtype=object)

# %%
plt.figure(figsize=(40, 40))
sns.heatmap(data.corr(),  annot=True, linewidths=0.5)
# plt.tight_layout()
# plt.show()

# %%
another_data = data.corr().unstack().sort_values().drop_duplicates().to_frame('new')

# %%
another_data
# Out:
#                                   new
# BsmtUnfSF     BsmtFinSF1    -0.495251
# BsmtFullBath  BsmtUnfSF     -0.422900
# EnclosedPorch YearBuilt     -0.387268
# LotFrontage   MSSubClass    -0.386347
# YearBuilt     OverallCond   -0.375983
# OverallCond   GarageYrBlt   -0.324297
# EnclosedPorch GarageYrBlt   -0.297003
# MSSubClass    1stFlrSF      -0.251758
# TotalBsmtSF   MSSubClass    -0.238518
# BsmtUnfSF     BsmtFinSF2    -0.209294
# 1stFlrSF      2ndFlrSF      -0.202646
# OverallCond   FullBath      -0.194149
# EnclosedPorch YearRemodAdd  -0.193919
# GarageCars    OverallCond   -0.185758
# KitchenAbvGr  OverallQual   -0.183882
# LowQualFinSF  YearBuilt     -0.183784
# KitchenAbvGr  YearBuilt     -0.174800
# TotalBsmtSF   2ndFlrSF      -0.174512
#               OverallCond   -0.171098
# BsmtFullBath  2ndFlrSF      -0.169494
# GarageArea    OverallCond   -0.151521
# GarageCars    EnclosedPorch -0.151434
# BedroomAbvGr  BsmtFullBath  -0.150673
# KitchenAbvGr  YearRemodAdd  -0.149598
# ...

# %%
#sns.countplot(x = '', data='dat
sns.lineplot(x='SalePrice',y='OverallQual', data=data)

# %% [markdown]
# Overall finishing quality is affecting the saleprice of house in range $1lakh to $3lakh and house more than $6.5lakh

# %%
# data['Alley'].unique()
sns.countplot(x='SalePrice',hue='Alley',data=data)

# %%
sns.scatterplot(x='SalePrice',y = 'PoolQC',data=data)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# ...

# %%
# data['Fence'] = data['Fence'].replace({:'noFence'})
data['Fence'].fillna(value='noFence', inplace=True)
# inputata['Fence']

# %%
data['Fence'].unique()
# Out:
# array(['noFence', 'MnPrv', 'GdWo', 'GdPrv', 'MnWw'], dtype=object)

# %%
sns.catplot(y= 'Fence',x='SalePrice', data=data)

# %% [markdown]
# #### Outcome:Feature 'Fence' has no bigger contribution to increase or decrease saleprice

# %%
data['MiscFeature'].unique()
data['MiscFeature'].fillna(value='NoSuchFeature', inplace=True)

# %%
sns.catplot(x= 'MiscFeature',y='SalePrice', data=data)

# %% [markdown]
# ### let's view the correlation of 'salePrice' with other 'Features'

# %%
corr_matrix=data.corr()
corr_mat = corr_matrix["SalePrice"].sort_values(ascending=False)
corr_mat
# Out:
# SalePrice        1.000000
# OverallQual      0.790982
# GrLivArea        0.708624
# GarageCars       0.640409
# GarageArea       0.623431
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# FullBath         0.560664
# TotRmsAbvGrd     0.533723
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# GarageYrBlt      0.486362
# MasVnrArea       0.477493
# Fireplaces       0.466929
# BsmtFinSF1       0.386420
# LotFrontage      0.351799
# WoodDeckSF       0.324413
# 2ndFlrSF         0.319334
# OpenPorchSF      0.315856
# HalfBath         0.284108
# LotArea          0.263843
# BsmtFullBath     0.227122
# BsmtUnfSF        0.214479
# BedroomAbvGr     0.168213
# ScreenPorch      0.111447
# PoolArea         0.092404
# MoSold           0.046432
# 3SsnPorch        0.044584
# BsmtFinSF2      -0.011378
# BsmtHalfBath    -0.016844
# MiscVal         -0.021190
# Id              -0.021917
# LowQualFinSF    -0.025606
# YrSold          -0.028923
# OverallCond     -0.077856
# ...

# %%
corr_mat[1:7]
# Out:
# OverallQual    0.790982
# GrLivArea      0.708624
# GarageCars     0.640409
# GarageArea     0.623431
# TotalBsmtSF    0.613581
# 1stFlrSF       0.605852
# Name: SalePrice, dtype: float64

# %% [markdown]
# #### Features like  'OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea', 'TotalBsmtSF', '1stFlrSF' have more correlation with 'SalePrice' than other feature

# %%
sns.scatterplot(x='OverallQual', y='SalePrice',hue='Foundation', data=data)

# %% [markdown]
# #### Outcome:
# 1) OverallQual is linearly dependent to SalePrice
#
#
# 2) House with 'stone' foundation are extremly cheap and those of 'PConc' are more expensive.
#
#
#
# 3) One of the factor to add up overall quality of a house is their foundation build up by Pconc material.

# %%
# for i in data.columns:
#     print(i,':',data[i].unique())
#     print('\n')

# %%
sns.distplot(data['SalePrice'], bins=100)

# %% [markdown]
# #### 1) Maxium number of houses of boston has a price range between  $1lakh - $2lakh

# %%
from sklearn.feature_selection import f_regression

# %%
X = data.loc[:, data.columns != 'SalePrice']
Y= data['SalePrice']

# %%
f_regression(X, Y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-b08918d5d5df> in <module>()
# ----> 1 f_regression(X, Y)
#
# ~\Anaconda3\lib\site-packages\sklearn\feature_selection\univariate_selection.py in f_regression(X, y, center)
#     276         scores.
#     277     """
# --> 278     X, y = check_X_y(X, y, ['csr', 'csc', 'coo'], dtype=np.float64)
#     279     n_samples = X.shape[0]
#     280
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     571     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
#     572                     ensure_2d, allow_nd, ensure_min_samples,
# --> 573                     ensure_min_features, warn_on_dtype, estimator)
# ...

# %%
data.head(5)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC    Fence    MiscFeature  \
# 0         Lvl    AllPub    ...            0    NaN  noFence  NoSuchFeature
# 1         Lvl    AllPub    ...            0    NaN  noFence  NoSuchFeature
# 2         Lvl    AllPub    ...            0    NaN  noFence  NoSuchFeature
# 3         Lvl    AllPub    ...            0    NaN  noFence  NoSuchFeature
# 4         Lvl    AllPub    ...            0    NaN  noFence  NoSuchFeature
#
#   MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
col = data.columns
num_cols = data._get_numeric_data().columns
cat_cols = list(set(col) - set(num_cols))

# %%
for co in num_cols:
    sns.lineplot(x='SalePrice',y=co, data=data)
